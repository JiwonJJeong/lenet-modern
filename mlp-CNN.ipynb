# %% [markdown]
# # MLP to CNN
# This notebook will introduce the convolutional layer and the difference in a convolutional layer and a linear layer.
#
# We will perform add pertubations on the image dataset to visualize the idea of shift invariance through pooling.
